# %% [markdown]
# <a href="https://colab.research.google.com/github/kollurilakshmipriya516-maker/python_Programs_colab/blob/main/celcius_to_fahrenheit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
celcius=int(input("Enter temp in celcius"))
fahrenheit=(celcius*(9/5))+32
print(fahrenheit)
# Out:
# Enter temp in celcius25
# 77.0
