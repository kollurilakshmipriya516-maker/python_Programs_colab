# %% [markdown]
# <a href="https://colab.research.google.com/github/kollurilakshmipriya516-maker/python_Programs_colab/blob/main/days_to_years.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
days = int(input("Enter number of days: "))
years = days // 365
remaining_days = days % 365
months = remaining_days // 30
print("Years =", years)
print("Months =", months)
# Out:
# Enter number of days: 800
# Years = 2
# Months = 2
