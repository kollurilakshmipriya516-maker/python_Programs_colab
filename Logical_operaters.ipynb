# %% [markdown]
# <a href="https://colab.research.google.com/github/kollurilakshmipriya516-maker/python_Programs_colab/blob/main/Logical_operaters.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Check whether a number is divisible by 5 and 3
n=int(input("enter a num:"))
if(n%5==0 and n%3==0):
  print("Divisible")
else:
  print("Not Divisible")
# Out:
# enter a num:15
# Divisible

# %%
#Check whether a person can drive (age >= 18 and has license)
age=int(input("enter a num:"))
license=str(input("have license or not:"))
if(age>=18 and license=="yes"):
  print("can drive")
else:
  print("Can't drive")
# Out:
# enter a num:20
# have license or not:yes
# can drive

# %%
#Check whether a character is vowel or consonant
a=str(input("enter a character:"))
if(a=='A'or a=='E' or a=='I' or a=='O' or a=='U' or a=='a' or a=='e' or a=='i' or a=='o' or a=='u'):
  print("Vowel")
else:
  print("Consonant")
# Out:
# enter a character:a
# Vowel

# %%
#Check whether username or email is correct
username=input("Enter username:")
email=input("Enter email:")
if username=="xyz" or email=="xyz@gmail.com":
    print("one is Correct")
else:
    print("Incorrect")
# Out:
# Enter username:xyz
# Enter email:sd
# one is Correct

# %%
#Check whether number is negative or odd
n=int(input("Enter a num:"))
if (n<0 or n%2!=0):
    print("The number is negative or odd")
else:
    print("The number is neither negative nor odd")
# Out:
# Enter a num:3
# The number is negative or odd

# %%
#Create simple calculator using conditions
num1=int(input("Enter first number:"))
num2=int(input("Enter second number:"))
op=input("Enter operator(+, -, *, /): ")
if op=='+':
    print("Result =", num1+num2)
elif op=='-':
    print("Result =", num1-num2)
elif op=='*':
    print("Result =", num1*num2)
elif op=='/':
    if num2!=0:
        print("Result =", num1/num2)
    else:
        print("Division by zero is not allowed")
else:
    print("Invalid operator")
# Out:
# Enter first number:5
# Enter second number:10
# Enter operator(+, -, *, /): *
# Result = 50

# %%
#Check whether marks are between 35 and 100
marks=int(input("enter a marks:"))
if(marks>35 and marks<100):
  print("Yes")
else:
  print("no")
# Out:
# enter a marks:95
# Yes

# %%
#Check whether year is century year
year=int(input("Enter a year: "))
if year%100==0:
    print("Century year")
else:
    print("Not a century year")
# Out:
# Enter a year: 2020
# Not a century year

# %%
#Check whether number is multiple of 2 or 7
n=int(input("enter a number:"))
if(n%2==0 or n%7==0):
  print("yes")
else:
  print("no")
# Out:
# enter a number:14
# yes

# %%
#Create mini login system with 3 attempts
a=False
attempts=3
for i in range(3):
  while(attempts>0):
    name=input("enter name:")
    password=input("enter password:")
    if(name=="xyz" and password=="12345"):
      print("successfully login")
      a=True
      break
    else:
      attempts=attempts-i-1
      print("Invalid credentials")
      print(attempts,"attempts left")
  if a:
    break
if not a:
    print("Attempts are over")
# Out:
# enter name:xcv
# enter password:vbn
# Invalid credentials
# 2 attempts left
# enter name:xyz
# enter password:12345
# successfully login
