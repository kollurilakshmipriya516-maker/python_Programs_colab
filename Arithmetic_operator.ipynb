# %% [markdown]
# <a href="https://colab.research.google.com/github/kollurilakshmipriya516-maker/python_Programs_colab/blob/main/Arithmetic_operator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#simple interest
p=int(input("enter principle amount:"))
r=int(input("enter rate of interst:"))
t=int(input("enter time:"))
s=(p*t*r)/100
print(s)
# Out:
# enter principle amount:5000
# enter rate of interst:5
# enter time:2
# 500.0

# %%
#compound interst
p = float(input("Enter principal amount: "))
r = float(input("Enter rate of interest: "))
t = float(input("Enter time: "))
amount=p*(1+r/100)**t
c=amount-p
print("Amount =",amount)
print("Compound Interest =",c)
# Out:
# Enter principal amount: 5000
# Enter rate of interest: 10
# Enter time (years): 2
# Amount = 6050.000000000001
# Compound Interest = 1050.000000000001

# %%
#total marks and percentage
s1=int(input("Enter s1 marks"))
s2=int(input("Enter s2 marks"))
s3=int(input("Enter s3 marks"))
s4=int(input("Enter s4 marks"))
s5=int(input("Enter s5 marks"))
total_marks=s1+s2+s3+s4+s5
percenta1ge=(total_marks/5)
print("Total Marks=",total_marks)
print("Percentage=",int(percentage),"%")
# Out:
# Enter s1 marks100
# Enter s2 marks100
# Enter s3 marks100
# Enter s4 marks100
# Enter s5 marks100
# Total Marks= 500
# Percentage= 100 %

# %%
#convert Minutes into hours
min=int(input("enter minutes:"))
hour=min/60
print("hour=",int(hour))
# Out:
# enter minutes:120
# hour= 2

# %%
#Find last digit of number using modulus
n=int(input("enter a num:"))
last_digit=n%10
print("last digit=",last_digit)
# Out:
# enter a num:568
# last digit= 8

# %%
#Find square root using exponent operator
num=int(input("Enter a number:"))
sqrt=num**0.5
print("Square root=", int(sqrt))
# Out:
# Enter a number:25
# Square root= 5
